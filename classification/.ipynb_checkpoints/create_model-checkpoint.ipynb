# %% [markdown]
# # Código para seleção e criação do modelo

# %%
import numpy as np
import pandas as pd

# %%
def stratified_sample(df, col='CATEGORY', n_per_class=2):
    return df.groupby(col, group_keys=False).apply(
        lambda x: x.sample(min(len(x), n_per_class)))

# %%
data = pd.read_csv('products.tsv', sep='\t')
data.set_index('ID', inplace=True)
data['SMARTPHONE'] = (data.CATEGORY == 'celular-e-smartphone').astype(int)

stratified_sample(data)
# Out:
#                                          CATEGORY  \
# ID
# 455                          aparelho-de-telefone
# 413                          aparelho-de-telefone
# 595                capa-para-celular-e-smartphone
# 575                capa-para-celular-e-smartphone
# 1192                         celular-e-smartphone
# 1243                         celular-e-smartphone
# 1823                                     gabinete
# 1412                                     gabinete
# 1913                                 jogos-de-rpg
# 1843                                 jogos-de-rpg
# 1922  outros-acessorios-para-celular-e-smartphone
# 2314  outros-acessorios-para-celular-e-smartphone
# 2864                    placa-de-captura-de-video
# 2561                    placa-de-captura-de-video
# 3064                                  processador
# 3310                                  processador
# 3684                                           tv
# 3706                                           tv
#
#                                                  SOURCE  \
# ID
# 455   https://www.buscape.com.br/sem-fio-intelbras-t...
# 413      https://www.buscape.com.br/sem-fio-vtech-vt680
# 595   https://www.buscape.com.br/redirect_prod?id=46...
# 575   https://www.buscape.com.br/redirect_prod?id=46...
# 1192  https://www.buscape.com.br/smartphone-xiaomi-r...
# 1243  https://www.buscape.com.br/smartphone-asus-zen...
# 1823  https://www.buscape.com.br/redirect_prod?id=11...
# 1412  https://www.buscape.com.br/redirect_prod?id=11...
# 1913  https://www.buscape.com.br/redirect_prod?id=63...
# 1843  https://www.buscape.com.br/redirect_prod?id=63...
# 1922  https://www.buscape.com.br/redirect_prod?id=80...
# 2314  https://www.buscape.com.br/redirect_prod?id=80...
# 2864  https://www.buscape.com.br/redirect_prod?id=64...
# 2561  https://www.buscape.com.br/redirect_prod?id=64...
# 3064  https://www.buscape.com.br/redirect_prod?id=95...
# 3310  https://www.buscape.com.br/redirect_prod?id=95...
# 3684  https://www.buscape.com.br/smart-tv-hd-philco-...
# 3706  https://www.buscape.com.br/smart-tv-4k-ultra-h...
#
#                                                   TITLE  SMARTPHONE
# ID
# 455                           Sem Fio Intelbrás TS 3112           0
# 413                                 Sem Fio VTech VT680           0
# 595   Capa para Alcatel Pixi 3 3.5 Desert Camouflage...           0
# 575                Capa para LG G2 Cogumelos MP12862958           0
# 1192                Smartphone Xiaomi Redmi Note 5 64GB           1
# 1243  Smartphone Asus ZenFone 4 ZE554KL 64GB 6GB RAM...           1
# 1823   GABINETE AEROCOOL ATX GT WINDOW BLACK MP13471201           0
# 1412   Gabinete Gamer Ga133 Cyborg Sem Fonte Multilaser           0
# 1913                        Board Game - Munchkin Panic           0
# 1843    Dungeons & Dragons Castle Ravenloft - Boardgame           0
# 1922  Popsocket Original Coração Pb05, Pop Selfie, 1...           0
# 2314  Tampa Traseira Personalizada Motorola Moto G3 ...           0
# 2864          Placa Principal para Tv Philco PH50A30PSG           0
# 2561  Placa Pci Inverter LTF320AP08 para Tv Samsung ...           0
# 3064  Processador Quad Core I5 7640X 4.2Ghz 6Mb Lga2...           0
# 3310  PROCESSADOR XEON E3 LGA 1151 INTEL BX80677E312...           0
# 3684    Smart TV HD Philco LED 32 polegadas PH32C10DSGW           0
# 3706  Smart TV 4K Ultra HD LG LED 70 polegadas 70UK6...           0

# %%
print('Frequência das primeiras palavras de cada produto categorizado ' +
        'como celular')
phone_titles = data[data.CATEGORY == 'celular-e-smartphone'].TITLE
first_words = phone_titles.apply(lambda t: t.split()[0])

first_words.value_counts()
# Out:
# Frequência das primeiras palavras de cada produto categorizado como celular
# Smartphone    419
# Celular        61
# Name: TITLE, dtype: int64

# %%
clean_titles = phone_titles.apply(lambda t: ' '.join(t.split()[1:]))
smartphones = data[data.CATEGORY == 'celular-e-smartphone']
trimmed_smartphones_idx = smartphones.sample(frac=0.4).index
data.loc[trimmed_smartphones_idx, 'TITLE'] = clean_titles

# %%
data[data.CATEGORY == 'celular-e-smartphone'].sample(10)
# Out:
#                   CATEGORY                                             SOURCE  \
# ID
# 1228  celular-e-smartphone  https://www.buscape.com.br/smartphone-sony-xpe...
# 1087  celular-e-smartphone  https://www.buscape.com.br/smartphone-asus-zen...
# 1176  celular-e-smartphone   https://www.buscape.com.br/smartphone-lg-k8-k350
# 1311  celular-e-smartphone  https://www.buscape.com.br/smartphone-apple-ip...
# 889   celular-e-smartphone  https://www.buscape.com.br/smartphone-motorola...
# 1046  celular-e-smartphone  https://www.buscape.com.br/smartphone-xiaomi-m...
# 1245  celular-e-smartphone  https://www.buscape.com.br/smartphone-xiaomi-m...
# 1207  celular-e-smartphone  https://www.buscape.com.br/smartphone-apple-ip...
# 1073  celular-e-smartphone  https://www.buscape.com.br/smartphone-alcatel-...
# 992   celular-e-smartphone  https://www.buscape.com.br/smartphone-lenovo-v...
#
#                                                TITLE  SMARTPHONE
# ID
# 1228                  Smartphone Sony Xperia Z5 32GB           1
# 1087       Smartphone Asus ZenFone Zoom ZX551ML 64GB           1
# 1176                                      LG K8 K350           1
# 1311             Smartphone Apple iPhone 8 Plus 64GB           1
# 889   Smartphone Motorola Moto G 5S Plus XT1805 32GB           1
# 1046                            Xiaomi Mi Mix 2 64GB           1
# 1245                Smartphone Xiaomi Mi Mix 2S 64GB           1
# 1207                             Apple iPhone 6 64GB           1
# 1073                    Smartphone Alcatel A3 XL Max           1
# 992                   Smartphone Lenovo Vibe K6 32GB           1

# %%
from extract_features import get_df_attributes, attr_col_names

# %%
features = get_df_attributes(data)
stratified_sample(features)
# Out:
#                                          CATEGORY  \
# ID
# 0                            aparelho-de-telefone
# 314                          aparelho-de-telefone
# 848                capa-para-celular-e-smartphone
# 487                capa-para-celular-e-smartphone
# 1246                         celular-e-smartphone
# 1155                         celular-e-smartphone
# 1568                                     gabinete
# 1580                                     gabinete
# 1913                                 jogos-de-rpg
# 1904                                 jogos-de-rpg
# 2320  outros-acessorios-para-celular-e-smartphone
# 2045  outros-acessorios-para-celular-e-smartphone
# 2470                    placa-de-captura-de-video
# 2657                    placa-de-captura-de-video
# 3211                                  processador
# 3156                                  processador
# 3581                                           tv
# 3704                                           tv
#
# 848         0        0      0
# 487         0        0      0
# 1246        0        0      0
# 1155        0        0      0
# 1568        0        0      0
# 1580        0        0      0
# 1913        0        0      0
# 1904        0        0      0
# 2320        0        0      0
# 2045        0        0      0
# 2470        0        0      0
# 2657        0        0      0
# 3211        0        0      0
# 3156        0        0      0
# 3581        0        0      0
# 3704        0        0      0

# %%
clf_features = features[attr_col_names + ['SMARTPHONE']]
stratified_sample(clf_features, col='SMARTPHONE', n_per_class=5)
# Out:
#       re_smart  re_phone  re_celular  re_letra_num  re_capa  re_para  \
# ID
# 3768         1         0           0             1        0        0
# 3067         0         0           0             1        0        0
# 327          0         1           0             1        0        0
# 1750         0         0           0             1        0        0
# 1549         0         0           0             1        0        0
# 1064         1         1           0             1        0        0
# 1075         1         1           0             1        0        0
# 1252         0         0           1             1        0        0
# 966          1         1           0             1        0        0
# 1229         1         1           0             1        0        0
#
#       re_pelicula  re_plus  re_chip  re_MP  SMARTPHONE
# ID
# 3768            0        0        0      0           0
# 3067            0        0        0      0           0
# 327             0        0        0      0           0
# 1750            0        0        0      0           0
# 1549            0        0        0      0           0
# 1064            0        0        0      0           1
# 1075            0        0        0      0           1
# 1252            0        0        0      0           1
# 966             0        0        0      0           1
# 1229            0        0        0      0           1

# %%
from sklearn.linear_model import Perceptron
from sklearn.naive_bayes import BernoulliNB

from sklearn.model_selection import cross_val_score

# %%
perceptron = Perceptron(max_iter=1e4)
naive_bayes = BernoulliNB(binarize=None)

# %%
X = clf_features[attr_col_names].values
y = clf_features['SMARTPHONE'].values

# %%
def eval_model(model):
    return cross_val_score(model, X, y, scoring='roc_auc', cv=10)


def print_results(name, cv_score):
    print(name)
    print(f'{np.mean(cv_score):.3f} +- {np.std(cv_score):.3f}')

# %%
perceptron_res = eval_model(perceptron)

# %%
naive_bayes_res = eval_model(naive_bayes)

# %%
print_results('Perceptron', perceptron_res)
print()
print_results('Naive Bayes', naive_bayes_res)
# Out:
# Perceptron
# 0.714 +- 0.208
#
# Naive Bayes
# 0.803 +- 0.131

# %%
from scipy.stats import ttest_ind

test_result = ttest_ind(perceptron_res, naive_bayes_res)
print(f'p-value: {test_result.pvalue:.3f}')
if test_result.pvalue < 0.05:
    print(f'Classificadores com desempenhos distindos')
else:
    print(f'Não há evidências de que os classificadores tenham desempenhos diferentes')
# Out:
# p-value: 0.293
# Não há evidências de que os classificadores tenham desempenhos diferentes

# %% [markdown]
# Apesar de ambos os classificadores possuirem desempenhos semelhantes sobre este conjunto de dados,
# é interessante escolher um que consiga generalizar o aprendizado ao conjunto alvo.
#
# No caso, experimentei com ambos os classificadores, e Naive Bayes demonstrou ter resultados muito melhores que o Perceptron, em geral.
# Por isso, optei por usá-lo na versão final.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
model = naive_bayes

model.fit(X_train, y_train)
# probas = model.decision_function(X_test)
probas = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, probas)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(fpr, tpr)
for i, t in enumerate(thresholds):
    if i % 3 == 0:
        plt.text(fpr[i], tpr[i], f'{(t):.2f}')

plt.show()

# %%
import pickle

# %%
model.fit(X, y)
with open('model.clf', 'wb+') as f:
    serialized_model = pickle.dump(model, f)
