# %% [markdown]
# # Código para seleção e criação do modelo

# %%
import numpy as np
import pandas as pd

# %%
def stratified_sample(df, col='CATEGORY', n_per_class=2):
    return df.groupby(col, group_keys=False).apply(
        lambda x: x.sample(min(len(x), n_per_class)))

# %%
data = pd.read_csv('products.tsv', sep='\t')
data.set_index('ID', inplace=True)
data['SMARTPHONE'] = (data.CATEGORY == 'celular-e-smartphone').astype(int)

stratified_sample(data)
# Out:
#                                          CATEGORY  \
# ID
# 103                          aparelho-de-telefone
# 48                           aparelho-de-telefone
# 728                capa-para-celular-e-smartphone
# 571                capa-para-celular-e-smartphone
# 1237                         celular-e-smartphone
# 994                          celular-e-smartphone
# 1685                                     gabinete
# 1501                                     gabinete
# 1859                                 jogos-de-rpg
# 1824                                 jogos-de-rpg
# 1973  outros-acessorios-para-celular-e-smartphone
# 2340  outros-acessorios-para-celular-e-smartphone
# 2662                    placa-de-captura-de-video
# 2829                    placa-de-captura-de-video
# 3345                                  processador
# 3307                                  processador
# 3561                                           tv
# 3691                                           tv
#
#                                                  SOURCE  \
# ID
# 103   https://www.buscape.com.br/redirect_prod?id=37...
# 48    https://www.buscape.com.br/oferta/aparelho-de-...
# 728   https://www.buscape.com.br/redirect_prod?id=46...
# 571   https://www.buscape.com.br/redirect_prod?id=46...
# 1237  https://www.buscape.com.br/smartphone-apple-ip...
# 994   https://www.buscape.com.br/smartphone-motorola...
# 1685  https://www.buscape.com.br/redirect_prod?id=11...
# 1501  https://www.buscape.com.br/redirect_prod?id=11...
# 1859  https://www.buscape.com.br/redirect_prod?id=63...
# 1824  https://www.buscape.com.br/redirect_prod?id=63...
# 1973  https://www.buscape.com.br/redirect_prod?id=80...
# 2340  https://www.buscape.com.br/redirect_prod?id=80...
# 2662  https://www.buscape.com.br/redirect_prod?id=64...
# 2829  https://www.buscape.com.br/avermedia-game-capt...
# 3345  https://www.buscape.com.br/redirect_prod?id=95...
# 3307  https://www.buscape.com.br/redirect_prod?id=95...
# 3561  https://www.buscape.com.br/tv-full-hd-sony-led...
# 3691  https://www.buscape.com.br/smart-tv-full-hd-lg...
#
#                                                   TITLE  SMARTPHONE
# ID
# 103   Multitoc Telefone Gondola C / Fio Grafite MP11...           0
# 48    Aparelho Telefone de Mesa C / Fio - Branco - M...           0
# 728    Capa para LG G2 Mini Vasco da Gama 02 MP12866077           0
# 571        Capa para LG K7 Juventus Mooca 02 MP12863748           0
# 1237  Smartphone Apple iPhone XR 128GB Special Editi...           1
# 994   Smartphone Motorola Moto Z XT1650 64GB Power E...           1
# 1685  Gabinete Tt V200 Tempered Glass, Thermaltake, ...           0
# 1501  Gabinete Coolermaster Masterbox 5t ( turbo ) P...           0
# 1859     Space Alert Jogo de Tabuleiro Devir Board Game           0
# 1824  Sauron - Hobbit 3 Lord Of The Rings Funko Pop ...           0
# 1973  Pop Selfie Personalizado Suporte para Celular ...           0
# 2340  Rp 870Ns - Repetidor De Sinal Celular Nextel R...           0
# 2662  Placa Principal Bn94 - 09536h / Bn41 - 02307b ...           0
# 2829                          Avermedia Game Capture HD           0
# 3345  Processador Intel Xeon E5 - 2699 v3 de dezoito...           0
# 3307  Processador Dell 2 x Xeon E5 - 2630 v3 de oito...           0
# 3561       TV Full HD Sony LED 40 polegadas KDL-40R355B           0
# 3691      Smart TV Full HD LG LED 43 polegadas 43LJ5500           0

# %%
print('Frequência das primeiras palavras de cada produto categorizado ' +
        'como celular')
phone_titles = data[data.CATEGORY == 'celular-e-smartphone'].TITLE
first_words = phone_titles.apply(lambda t: t.split()[0])

first_words.value_counts()
# Out:
# Frequência das primeiras palavras de cada produto categorizado como celular
# Smartphone    419
# Celular        61
# Name: TITLE, dtype: int64

# %%
clean_titles = phone_titles.apply(lambda t: ' '.join(t.split()[1:]))
smartphones = data[data.CATEGORY == 'celular-e-smartphone']
trimmed_smartphones_idx = smartphones.sample(frac=0.4).index
data.loc[trimmed_smartphones_idx, 'TITLE'] = clean_titles

# %%
data[data.CATEGORY == 'celular-e-smartphone'].sample(10)
# Out:
#                   CATEGORY                                             SOURCE  \
# ID
# 1044  celular-e-smartphone  https://www.buscape.com.br/smartphone-zte-shad...
# 1257  celular-e-smartphone  https://www.buscape.com.br/smartphone-motorola...
# 1100  celular-e-smartphone   https://www.buscape.com.br/smartphone-mirage-71s
# 1310  celular-e-smartphone  https://www.buscape.com.br/smartphone-samsung-...
# 1063  celular-e-smartphone  https://www.buscape.com.br/smartphone-alcatel-...
# 993   celular-e-smartphone  https://www.buscape.com.br/smartphone-zte-blad...
# 1123  celular-e-smartphone  https://www.buscape.com.br/smartphone-motorola...
# 1165  celular-e-smartphone  https://www.buscape.com.br/smartphone-alcatel-...
# 1129  celular-e-smartphone  https://www.buscape.com.br/smartphone-alcatel-...
# 1054  celular-e-smartphone  https://www.buscape.com.br/smartphone-nokia-lu...
#
#                                                   TITLE  SMARTPHONE
# ID
# 1044                            Smartphone ZTE Shade L5           1
# 1257              Motorola Moto G 5 XT1676 16GB 3GB RAM           1
# 1100                                         Mirage 71S           1
# 1310                    Samsung Galaxy A7 SM-A750 128GB           1
# 1063                          Smartphone Alcatel Pop C3           1
# 993                             Smartphone ZTE Blade L5           1
# 1123  Smartphone Motorola Moto Z XT1650 64GB Style E...           1
# 1165             Smartphone Alcatel Pixi 4 (5) 5010 8GB           1
# 1129         Smartphone Alcatel One Touch Pixi OT-4007E           1
# 1054                         Smartphone Nokia Lumia 630           1

# %%
from extract_features import get_df_attributes, attr_col_names

# %%
features = get_df_attributes(data)
stratified_sample(features)
# Out:
#                                          CATEGORY  \
# ID
# 408                          aparelho-de-telefone
# 142                          aparelho-de-telefone
# 599                capa-para-celular-e-smartphone
# 794                capa-para-celular-e-smartphone
# 934                          celular-e-smartphone
# 1146                         celular-e-smartphone
# 1516                                     gabinete
# 1357                                     gabinete
# 1834                                 jogos-de-rpg
# 1883                                 jogos-de-rpg
# 2354  outros-acessorios-para-celular-e-smartphone
# 2105  outros-acessorios-para-celular-e-smartphone
# 3302         0           0             1        0        0            0
# 3080         0           0             0        0        0            0
# 3543         0           0             0        0        0            0
# 3442         0           0             0        0        0            0
#
#       re_plus  re_chip  re_MP
# ID
# 408         0        0      0
# 142         0        0      0
# 599         0        0      0
# 794         0        0      0
# 934         0        0      0
# 1146        0        0      0
# 1516        0        0      0
# 1357        0        0      0
# 1834        0        0      0
# 1883        0        0      0
# 2354        0        0      0
# 2105        0        0      0
# 2680        0        0      0
# 2564        0        0      0
# 3302        0        0      0
# 3080        0        0      0
# 3543        0        0      0
# 3442        0        0      0

# %%
clf_features = features[attr_col_names + ['SMARTPHONE']]
stratified_sample(clf_features, col='SMARTPHONE', n_per_class=5)
# Out:
#       re_smart  re_phone  re_celular  re_letra_num  re_capa  re_para  \
# ID
# 2429         0         0           0             1        0        0
# 3561         0         0           0             0        0        0
# 1867         0         0           0             0        0        0
# 3041         0         0           0             1        0        0
# 235          0         1           0             0        0        0
# 1226         1         1           0             0        0        0
# 1258         0         0           0             1        0        0
# 1106         1         1           0             1        0        0
# 1085         0         0           0             0        0        0
# 998          1         1           0             1        0        0
#
#       re_pelicula  re_plus  re_chip  re_MP  SMARTPHONE
# ID
# 2429            0        0        0      0           0
# 3561            0        0        0      0           0
# 1867            0        0        0      0           0
# 3041            0        0        0      0           0
# 235             0        0        0      0           0
# 1226            0        0        0      0           1
# 1258            0        0        0      0           1
# 1106            0        0        0      0           1
# 1085            0        0        0      0           1
# 998             0        0        0      0           1

# %%
from sklearn.linear_model import Perceptron
from sklearn.naive_bayes import BernoulliNB

from sklearn.model_selection import cross_val_score

# %%
perceptron = Perceptron(max_iter=1e4)
naive_bayes = BernoulliNB(binarize=None)

# %%
X = clf_features[attr_col_names].values
y = clf_features['SMARTPHONE'].values

# %%
def eval_model(model):
    return cross_val_score(model, X, y, scoring='roc_auc', cv=10)


def print_results(name, cv_score):
    print(name)
    print(f'{np.mean(cv_score):.3f} +- {np.std(cv_score):.3f}')

# %%
perceptron_res = eval_model(perceptron)

# %%
naive_bayes_res = eval_model(naive_bayes)

# %%
print_results('Perceptron', perceptron_res)
print()
print_results('Naive Bayes', naive_bayes_res)
# Out:
# Perceptron
# 0.805 +- 0.157
#
# Naive Bayes
# 0.830 +- 0.108

# %%
from scipy.stats import ttest_ind

test_result = ttest_ind(perceptron_res, naive_bayes_res)
print(f'p-value: {test_result.pvalue:.3f}')
if test_result.pvalue < 0.05:
    print(f'Classificadores com desempenhos distindos')
else:
    print(f'Não há evidências de que os classificadores tenham desempenhos diferentes')
# Out:
# p-value: 0.698
# Não há evidências de que os classificadores tenham desempenhos diferentes

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
model = perceptron

model.fit(X_train, y_train)
probas = model.decision_function(X_test)
fpr, tpr, thresholds = roc_curve(y_test, probas)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(fpr, tpr)
for i, t in enumerate(thresholds):
    plt.text(fpr[i], tpr[i], f'{(t):.2f}')

plt.show()

# %%
import pickle

# %%
model.fit(X, y)
with open('model.clf', 'wb+') as f:
    serialized_model = pickle.dump(model, f)
